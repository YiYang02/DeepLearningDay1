# %% [markdown]
# <a href="https://colab.research.google.com/github/YiYang02/DeepLearningDay1/blob/main/DeepLearning_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "yyang2@bowdoin.edu"
# !git config --global user.name "YiYang02"

# %%
# !git clone https://bagto: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@github.com/bagto/test
# Out:
# Cloning into 'test'...
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/bagto/test/'

# %%
# !wget https://hips.hearstapps.com/hmg-prod/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg -o img.jpg
# Out:
# dog-puppy-on-garden-royalty-free-image-1586966191.jpg
# dog-puppy-on-garden-royalty-free-image-1586966191.jpg.1
# dog-puppy-on-garden-royalty-free-image-1586966191.jpg.2
# dog-puppy-on-garden-royalty-free-image-1586966191.jpg.3
# dog-puppy-on-garden-royalty-free-image-1586966191.jpg.4
# dog-puppy-on-garden-royalty-free-image-1586966191.jpg.5
# dog-puppy-on-garden-royalty-free-image-1586966191.jpg.6
# img.jpg
# sample_data

# %%
from matplotlib import pyplot as plt
import numpy as np

# Load the image
image = plt.imread('dog-puppy-on-garden-royalty-free-image-1586966191.jpg')

# Make a copy of the array that can be modified
image = np.copy(image)

# Set the top right 30x30 pixels to black
image[:30, -30:, :] = [0, 0, 0]

# Display the modified image
plt.imshow(image)
plt.show()
